# %% [markdown]
# 미리 만들어 둔 명사 집합을 이용하여 2016-10-20 뉴스 기사를 term frequency matrix로 만든 뒤, 뉴스의 군집화를 수행합니다. Logistic Regression에 Lasso Regularization을 걸어서 각 군집의 키워드를 추출함으로써 그날 뉴스의 핫키워드를 추출해 보도록 하겠습니다.

# %%
noun_dictionary_fname = './data/news_noun_dictionary.txt'
tokenized_corpus_fname = './data/news_2016-10-20_article_all_normed_nountokenized.txt'

# %% [markdown]
# 2016-10-20일 뉴스에 대하여 CountVectorizer를 이용하여 term frequency matrix를 만든 뒤, 그날의 주요 뉴스들이 어떤 것들이 있었는지 군집화를 수행합니다. scikit learn의 KMeans는 sparse matrix로도 군집화를 수행할 수 있습니다.
#
# 이를 위하여, 이전 수업 때 수행했던 custom_tokenizer를 이용합니다. noun_dictionary는 텍스트 파일로 저장되어 있으므로, 파일을 open으로 열 때에는 반드시 encoding='utf-8'을 신경써 주세요.
#
#     [noun.strip() for noun in f]
#
# 위 구문에서 noun.strip()을 하면 줄바꿈 기호 '\n'이 사라집니다.

# %%
with open(noun_dictionary_fname, encoding='utf-8') as f:
    nouns_dictionary = [noun.strip() for noun in f]
    print(len(nouns_dictionary))

def custom_tokenize(doc):    
    def parse_noun(token):
        for e in reversed(range(1, len(token)+1)):
            subword = token[:e]
            if subword in nouns_dictionary:
                return subword
        return ''
    
    nouns = [parse_noun(token) for token in doc.split()]
    nouns = [word for word in nouns if word]
    return nouns

custom_tokenize('이번 국정농단의 사태에 대하여 뉴스를 이용한 분석을 수행합니다')
# Out:
# 45930
# ['이번', '국정농단', '사태', '대하여', '뉴스', '이용', '분석', '수행']

# %% [markdown]
# 2016-10-20 뉴스에 대하여 corpus를 만듦니다. corpus의 length도 확인합니다. 당일에 30,091개의 뉴스가 있습니다.

# %%
with open(tokenized_corpus_fname, encoding='utf-8') as f:
    tokenized_corpus_2016_1020 = [doc.strip() for doc in f]
len(tokenized_corpus_2016_1020)
# Out:
# 30091

# %% [markdown]
# CountVectorizer를 이용하여 term frequency matrix를 만듦니다. CountVectorizer가 띄어쓰기를 기준으로 term을 구분하지만, 우리는 명사만 미리 남겨뒀으므로 띄어쓰기를 이용한 tokenizer를 해도 괜찮습니다.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(min_df=0.005, max_df=0.8)
x_2016_1020 = vectorizer.fit_transform(tokenized_corpus_2016_1020)
print(x_2016_1020.shape)
# Out:
# (30091, 2631)

# %% [markdown]
# x\_2016\_1020의 각 column에 해당하는 단어를 decoding 하기 위하여 vectorizer.vocabulary\_로부터  int2vocab를 만들었습니다.

# %%
int2vocab = sorted(vectorizer.vocabulary_.items(), key=lambda x:x[1])
int2vocab = [word for word, idx in int2vocab]
print(int2vocab[50:55])
# Out:
# ['1년', '1명', '1시', '1시간', '1심']

# %% [markdown]
# 만들어진 x_2016_1020을 이용하여 Spherical kmeans를 수행하겠습니다. 이를 위하여 L2로 normalization을 수행한 뒤, 클러스터의 개수를 500개로 지정하여 k-means clustering을 수행합니다.
#
# 군집화나 토픽 모델링을 수행할 때에는 예상하는 것보다 군집/토픽의 개수를 크게 잡아주세요. 중복되는 군집이 등장하면 나중에 묶으면 됩니다. 하지만, 데이터에 노이즈가 있어서 다른 군집들이 하나의 군집으로 묶인다면 나중에 해석하기가 어려워집니다.
#
# 특히, 여러 군집/토픽에서 두루두루 사용될 수 있는 단어들이 이러한 노이즈 역할을 합니다. 이런 단어들을 미리 걸러낼 수 있다면 훨씬 더 정교한 모델링이 될 것입니다. (즉, 군집화나 토픽모델링에서는 불필요하다 생각되는 단어들을 과감히 쳐낼수록 결과가 깔끔합니다).  그렇지 않다면, 군집화/토픽모델링을 할 때 군집/토픽의 개수를 크게 잡아두면 좀 더 좋습니다.
#
# 어자피 k-means는 수렴을 빨리 하기 때문에 max_iter=20으로 설정하였으며, 매 iteration마다 얼마나 빠르게 수렴하는지 살펴보기 위해 verbose=1로 하였습니다. n_init=1로 설정하여 반복하지 않고 딱 한번만 군집화를 수행합니다.
#
# 군집화를 수행한 뒤, 20개의 군집들에 대하여 각 군집에 할당된 뉴스의 개수가 몇 개인지 출력합니다.

# %%
# %%time

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from collections import defaultdict

x_2016_1020 = normalize(x_2016_1020, axis=1, norm='l2')
kmeans = KMeans(n_clusters=500, max_iter=20, n_init=1, verbose=1)
clusters = kmeans.fit_predict(x_2016_1020)

clusters_to_rows = defaultdict(lambda: [])
for idx, label in enumerate(clusters):
    clusters_to_rows[label].append(idx)

for i in range(20):
    print('cluster # %d has %d docs' % (i, len(clusters_to_rows[i])))
# Out:
# Initialization complete
# Iteration  0, inertia 18954.453
# Iteration  1, inertia 15373.415
# Iteration  2, inertia 14879.748
# Iteration  3, inertia 14658.383
# Iteration  4, inertia 14524.223
# Iteration  5, inertia 14447.217
# Iteration  6, inertia 14403.025
# Iteration  7, inertia 14373.280
# Iteration  8, inertia 14349.241
# Iteration  9, inertia 14333.654
# Iteration 10, inertia 14323.728
# Iteration 11, inertia 14315.760
# Iteration 12, inertia 14311.132
# Iteration 13, inertia 14308.232
# Iteration 14, inertia 14306.179
# Iteration 15, inertia 14304.175
# Iteration 16, inertia 14301.995
# Iteration 17, inertia 14299.749
# Iteration 18, inertia 14297.100
# Iteration 19, inertia 14294.139
# cluster # 0 has 113 docs
# cluster # 1 has 104 docs
# cluster # 2 has 691 docs
# cluster # 3 has 40 docs
# cluster # 4 has 78 docs
# cluster # 5 has 77 docs
# cluster # 6 has 30 docs
# cluster # 7 has 17 docs
# cluster # 8 has 31 docs
# cluster # 9 has 55 docs
# cluster # 10 has 314 docs
# cluster # 11 has 55 docs
# cluster # 12 has 123 docs
# cluster # 13 has 35 docs
# cluster # 14 has 1 docs
# cluster # 15 has 55 docs
# cluster # 16 has 20 docs
# cluster # 17 has 280 docs
# cluster # 18 has 1050 docs
# cluster # 19 has 9 docs
# CPU times: user 53 s, sys: 96 ms, total: 53.1 s
# Wall time: 53 s

# %% [markdown]
# 군집 17번은 280개의 뉴스가 묶여있습니다 (이건 군집화를 할 때마다 달라지므로, 다시 실행시키시면 다른 숫자일겁니다). 이 군집에 대하여 키워드를 추출하기 위해서는, 17번 군집에 해당하는 뉴스의 label을 1로, 다른 뉴스들을 -1로 둔 뒤, 해당 군집 17번을 구분할 수 있는 주요 단어들을 L1 regularized logistic regression을 이용하여 뽑을 수도 있습니다.
#
# y를 만든 뒤, 혹시 하는 마음에 x_2016_1020.shape과 같은지 확인도 해봅시다.

# %%
cluster_aspect = 17
y = [1 if i in clusters_to_rows[cluster_aspect] else -1 for i in range(x_2016_1020.shape[0])]
len(y), x_2016_1020.shape
# Out:
# (30091, (30091, 2631))

# %% [markdown]
# LogisticRegression의 penalty를 'l1'으로 주고, Regularization cost를 5로 주었습니다. 키워드의 개수가 너무 많다면 C를 더 작게, 키워드의 개수가 너무 적다면 C를 좀 더 크게 조절할 수 있습니다.
#
#     유진 (14.231)
#     진행 (13.082)
#     디자이너 (11.458)
#     브랜드 (10.925)
#     마이데일리 (7.269)
#     헤라서울패션위크 (6.670)
#     동대문디자인플라자 (0.146
#
# 상위의 키워드를 선택하였더니, 동대문디자인플라자에서 열린 서울패션위크에 대한 이야기임을 추정할 수 있습니다.

# %%
from sklearn.linear_model import LogisticRegression

logistic_l1 = LogisticRegression(penalty='l1', C=5)
logistic_l1.fit(x_2016_1020, y)

keywords = sorted(enumerate(logistic_l1.coef_[0]), key=lambda x:x[1], reverse=True)[:30]
for word, score in keywords:
    if score == 0: break
    print('%s (%.3f)' % (int2vocab[word], score))
# Out:
# 유진 (14.231)
# 진행 (13.082)
# 디자이너 (11.458)
# 브랜드 (10.925)
# 마이데일리 (7.269)
# 헤라서울패션위크 (6.670)
# 동대문디자인플라자 (0.146)

# %% [markdown]
# 이번에는 관심있는 군집들에 대하여 키워드들을 뽑아내는 함수를 만들겠습니다. interested_clusters로 입력되는 클러슽들에 대하여 위처럼 각각의 클러스터에 대한 Regularized Logistic Regression을 이용하여 키워드를 추출합니다.
#
# Regularization cost와 키워드의 개수를 선택하기 위하여 print_keywords의 함수의 arguments에 이를 넣어둡니다. L1 Logistic Regression에서 coefficient가 0이라는 것은 classification에서 유의미한 변수가 아니라는 뜻입니다. 그렇기 때문에 아래의 구문을 넣어서 coefficient가 0보다 큰 단어들만을 선택합니다.
#
#     keywords = [int2vocab[word] for word, score in keywords if score > 0]

# %% [markdown]
# 아래와 같은 결과를 얻을 수 있습니다. 단어 선택과 같은 튜닝 과정없이 명사 추출 + k-means clustering + 키워드 추출만으로도 어느 정도 그날 뉴스의 토픽들을 살펴볼 수 있습니다.
#
# 이제 남은 일은, 좀 더 정확한 단어를 선택하여 군집화가 잘 되게 만들고, 키워드를 추출하기에 좋은 parameter를 찾는 것입니다.
#
# 하지만 이런 접근 방법에 한 가지 단점이 있습니다. 만약 18번 군집에 대한 키워드로 '디자이너'가 선택되었지만, 이 단어는 다른 군집에서의 키워드가 될 수도 있습니다. 다른 여러개의 군집에서도 키워드로 이용될 수 있는 단어라면, 18번 군집의 키워드로 선택이 되지 않을수도 있습니다. 근본적인 원인은 18번이 아닌 다른 군집에 실제 18번 군집과 비슷한 군집이 있기 때문입니다.

# %%
def print_keywords(interested_clusters, x, int2vocab, clusters_to_rows, C=2, topn=30):
    
    for cluster_id in interested_clusters:
        interested_docs = clusters_to_rows[cluster_id]
        print('\ncluster # %d keywords (from %d news)' % (cluster_id, len(interested_docs)))
        y = [1 if i in interested_docs else -1 for i in range(x_2016_1020.shape[0])]
        
        logistic_l1 = LogisticRegression(penalty='l1', C=C)
        logistic_l1.fit(x, y)

        keywords = sorted(enumerate(logistic_l1.coef_[0]), key=lambda x:x[1], reverse=True)[:topn]
        keywords = [int2vocab[word] for word, score in keywords if score > 0]
        print(' > %s' % (keywords))
        
interested_clusters = [i for i, labels in clusters_to_rows.items() if 50 < len(labels) < 500]
print_keywords(interested_clusters, x_2016_1020, int2vocab, clusters_to_rows, C=2)
# Out:
# cluster # 0 keywords (from 113 news)
#  > ['수애', '김영광', '생각', '모습', '시청률', '드라마', '로맨틱', '남자', '우리집', '라고', '구르미', '홍나리', '캐릭터', '10시', '열심히', '부담', '연하', '사랑']
#
# cluster # 1 keywords (from 104 news)
#  > ['뉴스1스타', '컬렉션', '디자이너', '서울', '헤라', '서울패션위크']
#
# cluster # 4 keywords (from 78 news)
#  > ['마이데일리', '기사', '제공', '사진', '라고', '음악', '피부', '배우', '엄마', '국내', '공개', '컬렉션', '지난', '이야기', '형사', '아빠']
#
# cluster # 5 keywords (from 77 news)
#  > ['서울경제', '공시', '20일']
#
# cluster # 9 keywords (from 55 news)
#  > ['김유정', '차태현', '기자', '박보검', '라고', '영화']
#
# cluster # 10 keywords (from 314 news)
#  > ['서울', '뉴스1', '제공', '현장', '관련', '코리아', '코스닥', '노선', '최순실', '이날', '지난', '장관', '진행', '서초구', '문화체육관광부', '19일', '공공기관', '김포공항역', '검거', '참가', '최대', '전일', '일본']
#
# cluster # 11 keywords (from 55 news)
#  > ['수상', '코리아', '2016', '기자', '서울', '시장', '개최', '기자회견', '한국일보', '20일', '규탄', '행사', '연합뉴스', '출신', '중단', '의견', '인권']
#
# cluster # 12 keywords (from 123 news)
#  > ['대통령', '최순실', '박근혜', '국민의당', '해야', '의장', '이런', '포인트', '기존', '회고록', '위기', '기록', '경북', '이란', '경기', '지지', '정치', '서울신문', '국회', '투자', '우병우', '더불어민주당', '새누리당', '여성', '필요', '문제', '대한', '수도', '사람', '하락']
#
# cluster # 15 keywords (from 55 news)
#  > ['함께', '사랑', '스타', '영화', '11월', '제작보고회', '오전']
#
# cluster # 17 keywords (from 280 news)
#  > ['유진', '진행', '디자이너', '브랜드', '마이데일리', '헤라서울패션위크']
#
# cluster # 20 keywords (from 203 news)
#  > ['경찰', '주변', '부검', '경찰관', '공격', '신고', '전국', '사건', '친구', '카드', '총격', '광주', '그림', '위반', '20대', '남성', '수사', '법원', '이런', '성능', '단체', '불법', '가족', '학교', '오패산', '문제', '관련', '했습니다', '소식', '있던']
#
# cluster # 21 keywords (from 123 news)
#  > ['대표', '통합', '지금', '위기', '개최', '정부', '대선', '요리', '전주', '주최', '나눔', '예술', '대만', '사장', '공장', '변화', '음식', '회장', '개인', '해결', '자리', '상반기', '제품', '활동', '00', '디자인', '컴퓨터', '보안', '중소기업', '자신']
#
# cluster # 24 keywords (from 308 news)
#  > ['드라마', '배우', '동네', '역시', '구르미', '소속사', '시상식', '마지막', '활동', '사랑', '이렇게', '캐릭터', '모델', '박보검', '시선', '그녀', '활약', '동시', '연예인', '인물', '한편', '아이돌', '주목', '엔터테인먼트', '시청자들', '예정', '행보', '콘텐츠', '작가', '이야기']
#
# cluster # 33 keywords (from 58 news)
#  > ['외국인', '지난', '매출액', '이상', '매출', '국내', '증가', '올해']
#
# cluster # 37 keywords (from 121 news)
#  > ['트럼프', '힐러리', '선거', '발언', '후보', '공화당', '뉴스', '이라고', '도널드', '지금', '페이스북', '대한', '뉴욕', '결과', '대통령', '대선', '사실', '특파원', '질문', '우리']
#
# cluster # 38 keywords (from 368 news)
#  > ['시청자들', '라고', '말하는', '모습', '사람', '나섰다', '공항', '너무', '사실', '식사', '잠시', '시작', '리얼', '알고', '고백', '선택', '요리', '이용', '저녁', '엄마', '캡처', '내가', '상황', '친구들', '제작진', '자신', '자리', '많이', '혼자', '인턴기자']
#
# cluster # 43 keywords (from 189 news)
#  > ['머니투데이', '기자', '전날', '김영']
#
# cluster # 45 keywords (from 139 news)
#  > ['패션위크', '서울', '중구', '을지로']
#
# cluster # 48 keywords (from 80 news)
#  > ['을지로', '전자신문', '취하고', '엔터온뉴스', '서울패션위크', '컬렉션']
#
# cluster # 52 keywords (from 74 news)
#  > ['버튼', '크기', '감상', '09', '눈물', '27', '뮤직비디오', '이미지', '방탄소년단']
#
# cluster # 57 keywords (from 76 news)
#  > ['조망', '펼쳐진다', '서울컬렉션', '디자이너', '패션', '헤라', '오후', '콜렉션', '서울패션위크', '리포트']
#
# cluster # 59 keywords (from 103 news)
#  > ['20일', '입구', '처음', '장관', '훈련', '경남', '연합뉴스', '2016', '장비', '경기', '오후', '기자', '회의', '세종', '오른쪽', '설치']
#
# cluster # 61 keywords (from 136 news)
#  > ['김선', '중구', '뉴시스', '컬렉션', '서울패션위크', '동대문디자인플라자', '디자이너', '사진']
#
# cluster # 63 keywords (from 56 news)
#  > ['02', '이데일리', '공시', '선수', '20일', '79', '참가', '12월', '전일', '계약', '규모', '대표이사', '했다고']
#
# cluster # 67 keywords (from 121 news)
#  > ['21', '2016', '49', '69']
#
# cluster # 68 keywords (from 106 news)
#  > ['사고', '폭발', '부검', '차량', '터널', '정확', '공장', '조사', '경찰', '진술', '오전', '작업', '김씨', '있습니다', '타고', '어제', '광주', '정도', '현장', '것으로']
#
# cluster # 71 keywords (from 420 news)
#  > ['지원', '정부', '분야', '추진', '통합', '기술', '예산', '확대', '자동', '계획', '화학', '중심', '가운데', '관련', '설립', '출범', '프로젝트', '인수', '승인', '우선', '인프라', '전략', '관리', '활성화', '개발', '전문', '11월', '운용', '진출', '고양']
#
# cluster # 72 keywords (from 252 news)
#  > ['행사', '개최', '진행', '취업', '이번', '참여', '4일', '부스', '충남', '참가', '대회', '마련', '11월', '비롯', '성공', '디자인', '경기', '전통', '임직원', '주민', '음식', '기부', '주제', '내년', '28일', '선정', '오후', '일자리', '지원', '예정']
#
# cluster # 74 keywords (from 54 news)
#  > ['2016년', '10월', '19일', '재배포', '금지', '사진', '필리핀']
#
# cluster # 75 keywords (from 84 news)
#  > ['네이버', '3월', '의장', '부사장', '대표이사', '대표']
#
# cluster # 78 keywords (from 80 news)
#  > ['발사', '실패', '무수단', '추정']
#
# cluster # 80 keywords (from 194 news)
#  > ['클린턴', '토론', '트럼프', '이라고', '공화당', '주장', '여성', '대선', '문제', '후보', '이에', '미국', '것으로']
#
# cluster # 81 keywords (from 78 news)
#  > ['제주', '공항', '운영', '관광객', '불법']
#
# cluster # 83 keywords (from 110 news)
#  > ['부산', '개최', '운영', '추진', '대회', '매각', '일자리', '방문', '행사', '경기', '공동', '대형', '배치', '주민', '올해']
#
# cluster # 84 keywords (from 138 news)
#  > ['박세', '일간스포츠', '컬렉션']
#
# cluster # 86 keywords (from 211 news)
#  > ['서비스', '이용', '제공', '플랫폼', '사업자', '정보', '차량', '사용', '기능', '홈페이지', '속도', '검색', '세계', '보안', '기술', '올해', '최초', '시장', '솔루션', '모바일', '이용자', '브랜드', '가능', '기대', '스마트', '예약', '페이스북', '온라인', '적용', '미리']
#
# cluster # 90 keywords (from 67 news)
#  > ['방지', '스포츠동아', '동아닷컴', '서울패션위크', '동대문디자인플라자', '헤라']
#
# cluster # 92 keywords (from 98 news)
#  > ['총장', '학생들', '이화여대', '의혹', '이대', '사퇴', '최순실', '학교']
#
# cluster # 95 keywords (from 210 news)
#  > ['입건', '혐의', '이들', '받고', '구속', '상당', '지난', '돈을', '직장', '걸쳐', '것으로', '경찰', '이상', '검거', '인터넷', '사용', '조사', '김씨', '경기', '사기', '적발', '교환', '부산', '뉴스1', '허위', '이용', '6월', '전기', '전남', '폭행']
#
# cluster # 96 keywords (from 108 news)
#  > ['선고', '기소', '상대', '재판', '회사', '처벌', '혐의', '총리', '사건', '징역', '형사', '법원', '피해자', '사기', '범행', '김씨', '운영', '원장', '뉴스1', '고문']
#
# cluster # 99 keywords (from 91 news)
#  > ['문재인', '뉴시스', '시리즈', '라움', '더불어민주당', '참석', '대표', '원내대표', '론칭', '제보', '사진', '서울', '취하고', '제3', '영상', '포즈']
#
# cluster # 100 keywords (from 228 news)
#  > ['영화', '관객들', '촬영', '생각', '순간', '개봉', '시리즈', '관객', '원작', '주연', '소설', '작품', '감독', '그들', '이야기', '배우', '형사', '관심', '친구', '자신', '미국', '시작', '연기', '뉴욕', '번째', '기대', '지난', '프랑스', '국내', '리포트']
#
# cluster # 103 keywords (from 66 news)
#  > ['고양', '박근혜', '개막', '체험', '대한민국', '2016']
#
# cluster # 107 keywords (from 89 news)
#  > ['서울', '오후', '전자발찌', '정부서울청사', '경찰', '따뜻', '성동구', '기자', '왼쪽', '병원', '64', '코스닥', '연합뉴스', '방문']
#
# cluster # 108 keywords (from 137 news)
#  > ['위치', '아파트', '주변', '우수', '분양', '관심', '개통', '입주', '지하', '확보', '인근', '설계', '단지', '공간', '편리', '가능', '활성화', '부지', '풍부', '규모', '지역', '구성', '세대', '관계자는', '이용', '최근', '예정', '지상', '부동산', '공급']
#
# cluster # 109 keywords (from 122 news)
#  > ['저작권자', '증거', '금지', '사람들', '이번', '생산', '경제', '총리', '제출', '199', '설명', '독일', '있습니다', '박람회', '마을', '콘텐츠', '동물', '출동', '출연', '측은', '정리', '다음', '01', '47', '15', '모두', '미국']
#
# cluster # 110 keywords (from 68 news)
#  > ['성동일', '영화', '맡았다', '서현진', '박근형', '수상', '저작권자', '홍대', '딱풀', '때문', '스포츠조선', '주지홍', '제작보고회', '사랑', '한편', '웃음', '가세', '개봉', '김윤혜', '콤비']
#
# cluster # 112 keywords (from 51 news)
#  > ['중구', '포토타임', '세계일보', '서울패션위크', '세상', '미디어', '보는']
#
# cluster # 116 keywords (from 146 news)
#  > ['동대문', '서울패션위크', '헤라', '22일']
#
# cluster # 121 keywords (from 56 news)
#  > ['루이', '윤상']
#
# cluster # 123 keywords (from 59 news)
#  > ['재단', '검찰', '확인', '미르', '수사', '설립', '조사', '고발', '최순실']
#
# cluster # 125 keywords (from 188 news)
#  > ['상승', '하락', '전날', '미국', '예상', '증시', '51', '기록', '달러', '시장', '강세', '이날', '지수', '힐러리', '거래', '22', '대비', '상승세', '마감', '금리', '이후', '평가', '클린턴', '이데일리', '확대', '전망', '회의', '가격', '전일', '발표']
#
# cluster # 126 keywords (from 151 news)
#  > ['이라고', '연구', '4분기', '실적', '전망', '영업이익', '올해', '내년', '3분기', '기대', '예상', '주가', '것으로', '매수', '성장', '개선', '투자', '기대감', '투자증권', '매출액', '매출', '가능성', '개편', '때문', '음원', '이익', '기자', '증가', '구조조정', '이데일리']
#
# cluster # 127 keywords (from 109 news)
#  > ['지역', '12월', '경제', '경우', '것으로', '앞으로', '평가', '이내', '선정', '미국', '다음', '매일신문', '우수', '허용', '지난', '등록', '최근', '활성화', '광주', '활용', '생산', '발생', '만족', '대학', '보고']
#
# cluster # 128 keywords (from 89 news)
#  > ['무대', '노래', '방송', '선보', '매력', '2016', '전자신문', '변신', '타이틀곡']
#
# cluster # 130 keywords (from 91 news)
#  > ['삼성전자', '갤럭시노트7', '소비자', '삼성', '교환', '소송', '장관', '부회장', '선임', '공항', '찬성', '피해']
#
# cluster # 131 keywords (from 95 news)
#  > ['승객', '열차', '김포공항역', '의식', '사고', '확인', '서울시', '지하철', '지적', '안전', '문제', '출발', '센서', '것으로', '대책', '김씨', '발생', '신고', '있습니다']
#
# cluster # 135 keywords (from 217 news)
#  > ['아시아경제', '관계자는', '경제', '방지', '최선', '전국', '스타일', '기획', '이번', '국내', '계획', '판매', '소개', '활동', '사용', '것으로', '이영', '주요', '도움', '개최', '5개', '주민들', '개선', '공동', '홈페이지', '홍보', '뷰티', '안전', '방문', '포함']
#
# cluster # 138 keywords (from 102 news)
#  > ['게임', '추가', '캐릭터', '콘텐츠', '출시', '모바일', '신규', '11월', '사용', '전원', '엄마', '보상', '금지', '특징', '공개', '문화', '이번', '진행', '공격', '이용자']
#
# cluster # 140 keywords (from 375 news)
#  > ['뉴시스', '과정', '실시', '이들', '지난', '건강', '어린', '불법', '20일', '진행', '있도록', '개최', '공사', '관리', '작품', '홈페이지', '수출', '대한', '판매', '광주', '사랑', '이용', '도로', '분야', '계획', '지정', '2016년', '공모', '점검', '가을']
#
# cluster # 143 keywords (from 85 news)
#  > ['총기', '사제', '사제총', '경찰관', '앵커', '제작', '인터넷', '1천', '남성', '발사', '전자발찌', '사용', '출동', '피의자', '실제']
#
# cluster # 145 keywords (from 89 news)
#  > ['회고록', '문재인', '현안', '안보', '대표', '비판', '새누리당', '조사', '고발', '대응', '관련', '북한', '기억', '정치', '입장', '상황', '더불어민주당', '대통령', '지지율']
#
# cluster # 150 keywords (from 77 news)
#  > ['스타', '함께', '71', '이데일리', '진행', '엔터테인먼트', '참석', '스튜디오', '론칭']
#
# cluster # 154 keywords (from 90 news)
#  > ['여성', '남성', '대한', '영향', '건강', '질환', '소설', '정부', '작가', '여성들', '작품', '실험']
#
# cluster # 156 keywords (from 291 news)
#  > ['사진', '뉴시스', '제공', '경남', '라스베이거스', '화려', '방문', '제1', '장관', '가운데', '개최']
#
# cluster # 161 keywords (from 57 news)
#  > ['201', '2016', '11', '27', '23']
#
# cluster # 162 keywords (from 101 news)
#  > ['여의도', '뉴시스', '국회', '기자간담회', '간사', '제보', '오전', '83', '서울', '영상', '인사말을', '사진']
#
# cluster # 165 keywords (from 71 news)
#  > ['을지로', '엑스포츠뉴스', '오후', '서울패션위크']
#
# cluster # 167 keywords (from 80 news)
#  > ['발매', '앨범', '콘서트', '예정', '발표', '그룹', '이번', '활동', '함께', '공개', '음악', '11월', '지난', '정규']
#
# cluster # 168 keywords (from 149 news)
#  > ['이데일리', '종합', '미디어', '제공', '경제', '9시', '현대자동차', '서울', '장관', '연출']
#
# cluster # 171 keywords (from 53 news)
#  > ['마이데일리', '사랑', '영화', '때문', '차태현']
#
# cluster # 176 keywords (from 111 news)
#  > ['복귀', '대표', '탈당', '정치', '가능성', '선언', '대통령', '민주당', '기자회견', '손학규', '경제', '의원', '의미', '정계복귀', '국민의당', '대한민국', '것으로', '함께']
#
# cluster # 177 keywords (from 95 news)
#  > ['수상', '강남구', '개봉', '코미디', '사랑', '이승', '제작보고회', '오전', '배우', '콤비']
#
# cluster # 179 keywords (from 93 news)
#  > ['뉴스1', '손학규', '정론관에서', '의원', '서울', '선언', '상임고문', '정계복귀', '여의도', '더불어민주당', '기자회견']
#
# cluster # 180 keywords (from 55 news)
#  > ['대변', '북한', '규탄', '미사일', '발사', '위협', '유엔', '우리', '이날', '일본', '내부']
#
# cluster # 182 keywords (from 55 news)
#  > ['여의도', '이데일리', '국회', '헤럴드', '정진석', '국정감사', '헤럴드경제', '원내대표', '우상호', '20일', '모두발언', '민정수석']
#
# cluster # 184 keywords (from 147 news)
#  > ['08', '2016', '19']
#
# cluster # 186 keywords (from 52 news)
#  > ['패션쇼', '미세먼지', '경기', '뉴시스', '협상', '화성', '기록', '오후', '제보', '파업', '영상', '부산']
#
# cluster # 188 keywords (from 74 news)
#  > ['헤라서울패션위크', '김창', '스타뉴스', '컬렉션', '동대문디자인플라자']
#
# cluster # 190 keywords (from 57 news)
#  > ['질투', '출연', '인스타그램', '배우', '화신', '인연', '연기', '함께', '사진', '활약']
#
# cluster # 191 keywords (from 109 news)
#  > ['교육', '대학', '학교', '대통령', '개발', '학생', '학생들', '학습', '미래', '대구', '글로벌', '대안', '운영', '평가', '토론', '강진', '취업', '부문']
#
# cluster # 193 keywords (from 63 news)
#  > ['3분기', '지난', '누적', '은행', '기록', '동기', '대비', '분기', '작년', '증가', '1조']
#
# cluster # 195 keywords (from 325 news)
#  > ['우리', '사람들', '희망', '시간', '유명', '생각', '것이다', '사회', '역사', '세상', '정도', '사람', '먹고', '자신', '인간', '변화', '요즘', '하나', '문제', '시작', '친구', '이렇게', '때문', '어떤', '일을', '아이들', '현실', '의사', '당시', '하지']
#
# cluster # 201 keywords (from 68 news)
#  > ['불독', '키미', '기념', '멤버', '발매', '세이', '싱글', '활동', '회사', '생각', '라고', '이날', '콘셉트', '데뷔', '사진', '형은', '이들', '기자', '전자신문']
#
# cluster # 204 keywords (from 176 news)
#  > ['대출', '규제', '대책', '정부', '부동산', '주택', '아파트', '지난주', '강화', '금리', '1인', '가격', '지방', '계속', '지난', '상승세', '서울', '수요', '공급', '올해', '내년', '인상', '시장', '수준', '최고', '부산', '가장', '2014년', '것으로', '돌파']
#
# cluster # 209 keywords (from 60 news)
#  > ['대선후보', '토론회', '미국', '힐러리', '민주당', '현지시간', '아시아경제', '3차', '토론', '연합뉴스', '관련', '네바다', '공화당', '라스베이거스', '대선']
#
# cluster # 215 keywords (from 81 news)
#  > ['외교', '협의체', '양국', '북한', '확장억제', '한미', '압박', '억제', '대북', '미국', '국방', '차원']
#
# cluster # 218 keywords (from 73 news)
#  > ['파업', '운행', '채용', '노조', '44']
#
# cluster # 236 keywords (from 157 news)
#  > ['서울', '시내', '21일', '서울신문', '공시', '건강', '우리나라', '회사', '공모', '매출', '종로구', '문재인', '외교부', '업체', '프랑스', '세미나', '지원', '박근혜', '매출액', '대회', '방문', '상장', '다음', '계약', '금융', '의장', '각각', '행사', '주제', '오전']
#
# cluster # 239 keywords (from 191 news)
#  > ['한국', '세계', '가치', '등록', '교류', '작품', '역할', '환경', '설명', '독립', '금융', '이라고', '아시아', '영향', '건설', '14일', '선정', '영국', '전시', '대전', '발전', '시간', '로봇', '협력', '졸업', '자료', '소장', '제1', '시장', '규제']
#
# cluster # 242 keywords (from 77 news)
#  > ['고문', '정치', '나라', '손학규', '저의', '있습니다', '정계', '대한민국', '상임고문', '선언', '기자회견', '복귀', '생활', '탈당', '의원', '대통령', '강진']
#
# cluster # 244 keywords (from 53 news)
#  > ['극본', '우리', '참석', '김정민', '월화드라마', '영등포구', '텐아시아', '스포츠서울', '수애', '이수혁', '연출', '김영광', '포토타임', '아모리스']
#
# cluster # 245 keywords (from 123 news)
#  > ['국정원장', '브리핑', '회고록', '원장', '국정원', '공개', '의원', '자료', '질문', '정보위', '당시', '북한', '의견', '간사', '사실']
#
# cluster # 255 keywords (from 55 news)
#  > ['최순실씨', '최순실', '스포츠재단', '스포츠', '장애인', '독일', '설립', '해외', '미르재단', '회사', '것으로', '의혹', '사업', '운영', '실세', '최씨', '가방', '지난', '있습니다', '논란', '관련']
#
# cluster # 262 keywords (from 60 news)
#  > ['시청률', '방송', '기록', '19일', '질투']
#
# cluster # 264 keywords (from 148 news)
#  > ['교수', '연구', '효과', '기존', '환자', '그룹', '서울대', '대한', '치료', '것으로', '개발', '결과', '교체', '사용', '미국', '발견', '유도']
#
# cluster # 267 keywords (from 75 news)
#  > ['2015', '2016', '19', '26', '03']
#
# cluster # 269 keywords (from 172 news)
#  > ['중국', '추진', '때문', '2억', '국가', '포인트', '노선', '인수', '아시아', '인도', '트위터', '광주', '세계', '우리나라', '하나', '스마트폰', '국내', '경남', '업체', '방문', '내년', '베트남', '경제', '평균', '규모', '시장', '요구', '지난', '이름', '올해']
#
# cluster # 270 keywords (from 60 news)
#  > ['사장', '고문', '재판', '소송', '판결', '측은', '법원', '이혼', '사람', '1심']
#
# cluster # 272 keywords (from 92 news)
#  > ['북한', '통신', '주장', '유엔', '대북', '우리', '연기', '동물', '러시아', '소개', '금지', '지난', '주민']
#
# cluster # 276 keywords (from 51 news)
#  > ['손학규', '민주당', '이정', '정론관에서', '발표', '연합뉴스', '오후', '서울', '대표', '80']
#
# cluster # 279 keywords (from 78 news)
#  > ['조망', '콜렉션', '디자이너', '펼쳐진다', '오전', '헤라', '41개', '서울패션위크', '동대문디자인플라자', '리포트']
#
# cluster # 280 keywords (from 60 news)
#  > ['동명', '제작발표회', '우리', '작품', '날벼락', '하늘', '참석', '마른', '포즈', '취하고', '07']
#
# cluster # 287 keywords (from 123 news)
#  > ['서울경제', '12월', '소개', '상담', '이날', '2조', '00', '부회장', '증거', '진행', '건강', '학교', '모집', '배우', '서울대', '규모', '최대', '거래', '각각', '지난', '가능성', '시스템', '사용', '논의', '것이다', '73', '모델', '관심', '출시', '라고']
#
# cluster # 288 keywords (from 84 news)
#  > ['정부서울청사', '뉴시스', '제보', '종로구', '공공기관']
#
# cluster # 292 keywords (from 109 news)
#  > ['투자', '글로벌', '상품', '발행', '미국', '금리', '설명', '국내', '은행', '세미나', '중동', '부동산', '이상', '투자자들', '내년', '회장', '규모', '전망', '유럽']
#
# cluster # 294 keywords (from 128 news)
#  > ['기업', '임직원', '성장', '2013년', '주가', '변화', '코리아', '활동', '수상', '가능', '공시', '발행', '개편', '경험', '종목', '디지털', '경영', '이들', '없이', '회사', '베트남', '금액', '필요', '진행', '기록', '산업', '경제', '주식', '제공']
#
# cluster # 301 keywords (from 109 news)
#  > ['경위', '경감', '빈소', '오패산터널', '금지', '김창', '22일', '경찰', '지난', '근무', '노컷뉴스', '동료', '강북구', '안전', '뉴스1', '순직']
#
# cluster # 302 keywords (from 83 news)
#  > ['충돌', '성씨', '전자발찌', '검거', '소리', '발사', '인근', '신고', '출동', '오패산터널', '자신', '총격', '용의자', '오후', '징역', '경찰', '도착', '6시', '범인', '시민들', '가는', '혐의', '현장', '피의자', '터널', '19일', '경위', '당시']
#
# cluster # 303 keywords (from 61 news)
#  > ['러시아', '사태', '총리', '유엔', '독일', '대통령', '현지시간', '연장', '미국', '예정', '프랑스']
#
# cluster # 311 keywords (from 74 news)
#  > ['청약', '84', '분양', '전용', '기록', '평균', '10대', '61', '74', '진행', '공급', '경기', '규모', '27일', '21', '계약', '59', '건설', '모집', '단지']
#
# cluster # 313 keywords (from 57 news)
#  > ['울산', '친환경', '계획', '대한', '84', '지원', '구축', '전국', '단지']
#
# cluster # 317 keywords (from 89 news)
#  > ['멤버', '방지', '참석', '동아닷컴', '서울패션위크', '스포츠동아']
#
# cluster # 319 keywords (from 55 news)
#  > ['강수지', '라고', '사람', '애정']
#
# cluster # 322 keywords (from 63 news)
#  > ['공효진', '조정석', '질투', '연기', '웃음', '화신', '방송', '선보', '촬영', '모습', '매력']
#
# cluster # 326 keywords (from 157 news)
#  > ['고객', '이벤트', '할인', '상품', '가입', '포인트', '증정', '혜택', '제공', '기념', '기능', '가능', '구매', '예약', '페이스북', '진행', '출시', '기존', '최대', '투자자', '판매', '시리즈', '무기', '추가', '이번', '지난', '학습', '디지털', '소통', '캐릭터']
#
# cluster # 330 keywords (from 83 news)
#  > ['연합뉴스', '20일', '대한민국', '제공', '사랑', '초청', '발전', '대전', '광주', '평화', '구조', '차량', '주관', '지역', '시내', '부작용', '특파원', '무료', '대구']
#
# cluster # 333 keywords (from 137 news)
#  > ['여의도', '국회', '뉴스1', '국가인권위원회', '국민의당', '원내수석부대표', '원내대표', '대한', '서울', '정진석']
#
# cluster # 336 keywords (from 104 news)
#  > ['서울시', '여의도', '단속', '시민들', '개발', '결정', '계획', '시민', '상징', '관광', '평가', '가능', '운행', '공간', '주변', '예정', '공공', '운영', '지정']
#
# cluster # 337 keywords (from 68 news)
#  > ['우병우', '청와대', '수사', '사유서', '수석', '증인', '위원장', '이하', '원내대표', '의혹', '이유', '거부', '운영위', '국회', '대통령', '의결', '불출석', '박지원', '국민', '국감']
#
# cluster # 339 keywords (from 55 news)
#  > ['라디오스타', '방송', '이날', '19일', '특집', '출연', '어머니', '프로그램', '사람', '많이', '예능', '웃음', '연예인', '좋아', '게스트', '전화', '얘기', '하지']
#
# cluster # 341 keywords (from 51 news)
#  > ['후보', '라스베이거스', '네바다', '대학', '금지', '대선', '3차', '토론', '미국', '공화당', '뉴스1', '뉴시스']
#
# cluster # 345 keywords (from 414 news)
#  > ['서울', '제보', '영상', '사진', '경위', '대한', '진행', '21', '뉴시스', '서비스', '서울시', '행사', '사장', '조성', '전경련', '99', '검찰', '2016', '서초구', '출시', '미래창조과학부', '중구', '지난', '앞둔', '초청', '송파구', '경찰']
#
# cluster # 349 keywords (from 96 news)
#  > ['제보', '뉴시스', '20일', '영상', '전주', '발사', '수원', '춘천', '울산', '역량', '차단']
#
# cluster # 353 keywords (from 58 news)
#  > ['방탄소년단', '1위', '앨범', '해외']
#
# cluster # 360 keywords (from 77 news)
#  > ['화보', '인터뷰', '모델', '스타일', '가을', '예능', '남자', '이번', '멤버', '완벽', '제공', '촬영', '변신', '특히', '미란다', '라고', '면모']
#
# cluster # 362 keywords (from 140 news)
#  > ['공연', '콘서트', '함께', '23일', '30분', '음악', '페스티벌', '올해', '대학', '특히', '아티스트', '노래', '학생들', '최고', '예정', '이번', '축제', '관객', '제공', '광주', '무료', '25일']
#
# cluster # 363 keywords (from 113 news)
#  > ['제품', '판매', '최근', '가능', '피부', '특히', '방식', '애플', '신제품', '도움', '매출', '차량', '국내', '전자신문', '때문', '지난', '출시', '내부', '미국', '증가', '수입', '동시']
#
# cluster # 366 keywords (from 84 news)
#  > ['차태현', '연기', '기억', '사랑', '때문', '영화', '서현진', '라이브', '웃음', '함께', '스타', '감독', '많이']
#
# cluster # 374 keywords (from 163 news)
#  > ['반론', '권리', '접근', '주제', '78', '있습니다', '국민', '역할', '모습', '이번', '가구', '여성', '지난', '인터넷', '사랑', '참여', '이름', '반대', '10월', '개최', '우리']
#
# cluster # 391 keywords (from 90 news)
#  > ['박주', '선언', '뉴시스', '여의도', '민주당', '손학규', '사진', '정론관에서', '국민의당', '정계', '서울', '복귀', '제보']
#
# cluster # 395 keywords (from 114 news)
#  > ['보는', '세계', '기자', '아시아경제', '규모', '실시', '코스닥', '하락', '20일']
#
# cluster # 403 keywords (from 256 news)
#  > ['뉴스1', '25일', '관계자는', '홍보', '신속', '노력', '23일', '충북', '경남', '등록', '공원', '인구', '20일', '일부', '보존', '제공', '이날', '광주', '규모', '활동', '실시', '기존', '현지시간', '정책', '기자', '마을', '차량', '9월', '가운데', '대회']
#
# cluster # 407 keywords (from 112 news)
#  > ['회장', '세계', '통일', '경영', '매일신문', '대한민국', '그룹', '상장', '선거', '사회', '대구', '지역', '설치']
#
# cluster # 410 keywords (from 154 news)
#  > ['의원', '내용', '국회', '문제', '제출', '의원들', '위원장', '요구', '이성', '더민주', '야당', '예산', '의장', '이전', '필요', '정책', '지원', '학교', '발언', '추진', '국정감사', '장애인', '내년', '지적', '반대', '정치', '대구', '규정', '새누리당', '운영']
#
# cluster # 416 keywords (from 107 news)
#  > ['검찰', '수사', '조사', '관련', '지난', '오늘', '부회장', '롯데', '비리', '추가', '회장', '부당', '인수', '2011년', '회사', '대출', '그룹', '혐의', '대한', '확보', '것으로', '2014년', '자료', '한국경제', '검사']
#
# cluster # 417 keywords (from 80 news)
#  > ['지진', '규모', '훈련', '발생', '일본']
#
# cluster # 418 keywords (from 52 news)
#  > ['오전', '19일', '21일', '10시', '02', '오후', '8시', '22일', '인천', '44', '원장', '매일경제', '00']
#
# cluster # 425 keywords (from 202 news)
#  > ['프로그램', '체험', '축제', '가을', '힐링', '운영', '참여', '학생들', '강연', '전시', '진행', '역량', '아름다운', '대구', '취업', '코스', '주제', '직접', '문화', '함께', '전국', '서울신문', '경주', '기회', '캠페인', '10월', '비롯', '공모', '소개', '특히']
#
# cluster # 428 keywords (from 101 news)
#  > ['성병대', '범행', '경찰', '앵커', '오늘', '총격', '기자', '사제', '있습니다', '경감', '피의자', '자신', '사용', '전자발찌', '경찰관', '시민', '김창', '구속영장', '사제총', '6시']
#
# cluster # 429 keywords (from 234 news)
#  > ['사진', '인스타그램', '지난', '잡고', '카메라', '미소', '온라인', '자신', '이슈', '함께', '한편', '유리', '공개', '스포츠조선', '모습', '영상', '데뷔', '동영상', '시간', '우리', '소속사', '올렸다', '박보검', '행복', '브랜드', '화제', '머리', '자랑', '매일경제', '콘텐츠']
#
# cluster # 436 keywords (from 255 news)
#  > ['적용', '선보', '출시', '소재', '디자인', '컬렉션', '날씨', '브랜드', '보관', '라인', '기념', '사용', '착용', '블랙', '패션', '이미지', '전용', '디자이너', '유명', '선택', '아이템', '공간', '활용', '겨울', '전통', '가을', '컬러', '있도록', '이번', '신제품']
#
# cluster # 451 keywords (from 351 news)
#  > ['방송', '출연', '제가', '웃음', '데이트', '지목', '파워', '언급', '라디오', '소개', '좋아', '예능', '솔직', '이에', '20일', '이날', '뷰티', '어떤', '노래', '탄생', '멤버', '너무', '공개', '24', '음악', '활동', '방송화면', '깜짝', '오후', '계속']
#
# cluster # 453 keywords (from 150 news)
#  > ['일본', '예정', '노선', '관련', '해외', '총리', '체결', '본사', '해상', '걸그룹', '근무', '생산', '경기', '개최', '평균', '합의', '달러', '필리핀', '여행', '정부', '제주', '인정', '이후', '지난', '해도', '최근']
#
# cluster # 465 keywords (from 56 news)
#  > ['영업이익', '당기순이익', '공시', '집계', '기간', '기준', '3분기', '올해', '한국경제', '각각', '22', '증가', '재배포', '동기', '매출', '기자', '금지', '뉴시스']
#
# cluster # 467 keywords (from 145 news)
#  > ['제공', '서울', '연합뉴스', '20일', '문화체육관광부', '서울시', '진행', '직원들', '공간', '왼쪽', '오른쪽', '기념촬영', '베트남']
#
# cluster # 476 keywords (from 129 news)
#  > ['사업', '추진', '조성', '개발', '가능', '내년', '마을', '엄마', '선정', '이상', '경남', '개설', '시장', '보안', '전력', '설치', '계획', '부지', '유치', '지난', '행복']
#
# cluster # 482 keywords (from 489 news)
#  > ['기자', '패션쇼', '페이지', '꿈꾸는', '금지', '형성', '후원', '전반', '선발', '20일', '연예뉴스', '전면', '불법', '이날', '있습니다', '일정', '2017', '디자이너', '능력', '현지', '스포츠조선', '29', '광주', '소식', '도전', '홈페이지', '자리', '헤럴드경제', '해당', '영국']
#
# cluster # 487 keywords (from 52 news)
#  > ['혐의', '선거', '증권사', '대가', '위반', '비서실장', '학교', '검찰', '자리', '변호사', '특정', '지난']
#
# cluster # 489 keywords (from 143 news)
#  > ['재배포', '무단', '조선일보', '백화점', '꿈꾸는', '금지', '유일', '2014년', '헤럴드경제', '치료', '최대', '디지털타임스', '뉴스', '제공', '행정', '왼쪽', '헤럴드', '개최', '대한', '더불어민주당', '오늘', '먼저', '서울', '사고', '자세', '회장', '작가']
#
# cluster # 495 keywords (from 52 news)
#  > ['10시', '동명', '남자', '조보아', '촬영', '제작발표회', '우리집', '캐릭터', '후속', '이수혁', '한편']
